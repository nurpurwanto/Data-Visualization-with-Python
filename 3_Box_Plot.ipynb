# %% [markdown]
# ## Load dataset

# %% [markdown]
# Dataset yang digunakan adalah dataset <a href='https://www.kaggle.com/szamil/who-suicide-statistics'>WHO Suicide Statistics</a> yang terdiri dari 43776 baris dan 6 kolom.
#
# __Feature Information:__
#
# * __country :__ nama negara yang terdata
# * __year :__ tahun
# * __sex :__ jenis kelamin
# * __age :__ rentang usia
# * __suicides_no :__ jumlah orang yang melakukan bunuh diri
# * __population :__ populasi penduduk

# %% [markdown]
# Pertama <i>import</i> dahulu <i>library</i> yang akan digunakan yaitu Pandas dan Matplotlib.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('seaborn')    # style matplotlib

# %% [markdown]
# Kemudian <i>load</i> dataset menggunakan <code>read_csv()</code> dan menyimpannya dalam variabel <code>df</code>.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/Colab Notebooks/DATASET/datasets_py/
# Out:
# /content/gdrive/My Drive/Colab Notebooks/DATASET/datasets_py

# %%
df = pd.read_csv("who_suicide_statistics.csv")
df.head(10)
# Out:
#    country  year     sex          age  suicides_no  population
# 0  Albania  1985  female  15-24 years          NaN    277900.0
# 1  Albania  1985  female  25-34 years          NaN    246800.0
# 2  Albania  1985  female  35-54 years          NaN    267500.0
# 3  Albania  1985  female   5-14 years          NaN    298300.0
# 4  Albania  1985  female  55-74 years          NaN    138700.0
# 5  Albania  1985  female    75+ years          NaN     34200.0
# 6  Albania  1985    male  15-24 years          NaN    301400.0
# 7  Albania  1985    male  25-34 years          NaN    264200.0
# 8  Albania  1985    male  35-54 years          NaN    296700.0
# 9  Albania  1985    male   5-14 years          NaN    325800.0

# %% [markdown]
# Selanjutnya mari mulai <i>plotting</i> data.

# %% [markdown]
# ## Visualisasi data dengan Box Plot

# %% [markdown]
# __Box plot__ adalah jenis visualisasi data yang secara statistik merepresentasikan distribusi data melalui lima dimensi utama, yaitu nilai minimum, kuartil 1, kuartil 2 (median), kuartil 3, dan nilai maksimum. Biasanya box plot digunakan untuk memeriksa keberadaan <i>outlier</i> dalam dataset.
#
# Sebelum mulai membuat <i>box plot</i>, siapkan datasetnya terlebih dahulu. Disini kita akan melakukan <i>reshaping</i> atau mengubah bentuk dataset menjadi bentuk <i>pivot table</i>.
#
# Di Python, gunakan <i>method</i> <code>pivot_table()</code> dengan memberikan beberapa parameter seperti <code>index</code>, <code>columns</code>, <code>values</code>, dan <code>aggfunc</code>.
#
# Jadikan <code>country</code> sebagai indeks, <code>year</code> sebagai kolom, <code>suicide_no</code> sebagai nilainya, dan <code>sum</code> sebagai fungsi agregasinya.

# %%
# Reshaping data

df_pivot = df.pivot_table(index='country', columns='year', values='suicides_no', aggfunc='sum')
df_pivot
# Out:
# year                                  1979    1980    1981    1982    1983  \
# country
# Albania                                NaN     NaN     NaN     NaN     NaN
# Anguilla                               NaN     NaN     NaN     NaN     0.0
# Antigua and Barbuda                    NaN     NaN     NaN     NaN     0.0
# Argentina                           1802.0  1972.0  2197.0  1965.0  1834.0
# Armenia                                NaN     NaN    92.0    70.0     0.0
# ...                                    ...     ...     ...     ...     ...
# Uruguay                                0.0   274.0   261.0   318.0   323.0
# Uzbekistan                             NaN     NaN  1149.0  1134.0     0.0
# Venezuela (Bolivarian Republic of)   589.0   720.0   669.0   686.0   785.0
# Virgin Islands (USA)                   NaN     3.0     0.0     0.0     NaN
# Zimbabwe                               NaN     NaN     NaN     NaN     NaN
#
# ...

# %% [markdown]
# Setelah mendapatkan dataframe yang ideal, langsung membuat visualisasi data.

# %% [markdown]
# ### Single Boxplot

# %% [markdown]
# Pertama membuat <i>single box plot</i>. Visualisasi data dengan <i>box plot</i> untuk data negara __Japan__.
#
# Sebelumnya, buat list tahun terlebih dahulu yang nantinya berfungsi untuk melakukan <i>filter</i> data.

# %%
# Membuat list tahun

years = list(range(1980, 2016))
years
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015]

# %% [markdown]
# Kemudian <i>filter</i> data menggunakan <code>loc</code> dengan memberikan nilai <code>['Japan']</code> sebagai indeks yang akan dipilih dan list <code>years</code> yang baru saja dibuat di atas sebagai kolom yang dipilih.
#
# lakukan juga <code>transpose()</code> dataframe. Perhatikan kode di bawah ini.

# %%
# Filter dan transpose dataframe

df_japan = df_pivot.loc[['Japan'], years].transpose()
df_japan.head()
# Out:
# country    Japan
# year
# 1980     20416.0
# 1981     19976.0
# 1982     20535.0
# 1983     24853.0
# 1984     24221.0

# %% [markdown]
# Selanjutnya buat <i>box plot</i> dengan kode di bawah ini. Pastikan parameter <code>kind = 'box'</code> untuk menandakan bahwa visualisai yang ingin dibuat adalah <i>box plot</i>.

# %%
# Membuat box plot

df_japan.plot(kind='box', figsize=(8, 6))

plt.title('Box plot of Suicide Cases in Japan from 1980 - 2015\n', size=16)
plt.ylabel('Number of Suicide Cases\n', size=14)
plt.xticks(size=14)
plt.yticks(size=14)

plt.show()

# %% [markdown]
# Dari visualisasi di atas, kita dapat mengamati sekilas tentang dataset, di antaranya:
#
# 1. Nilai minimum dari kasus bunuh diri di Jepang dari tahun 1980 - 2015 adalah kurang sedikit dari 20000 kasus.
# 2. Nilai maksimum dari kasus bunuh diri di Jepang dari tahun 1980 - 2015 adalah sekitar 32000.
# 3. Nilai median (kuartil 2) dari kasus bunuh diri di Jepang dari tahun 1980 - 2015 adalah sekitar 24500.
# 4. Kuartil 1 atau 25% dari periode 1980 - 2015 memiliki jumlah kasus tahunan sekitar 21000.
# 5. Kuartil 3 atau 50% dari periode 1980 - 2015 memiliki jumlah kasus tahunan sekitar 30000.
#
# Untuk melihat angka-angka sebenarnya, gunakan <i>method</i> <code>describe()</code> pada dataframe <code>df_japan</code> seperti di bawah ini.

# %%
# Melihat statistik dataframe

df_japan.describe()
# Out:
# country         Japan
# count       36.000000
# mean     25469.527778
# std       4201.238147
# min      19780.000000
# 25%      21190.000000
# 50%      24605.000000
# 75%      29824.000000
# max      31881.000000

# %% [markdown]
# ### Multiple Boxplot

# %% [markdown]
# Membuat beberapa <i>box plot</i> di dalam satu axes. Jika tadi hanya mengamati negara Jepang, sekarang akan mengamati beberapa negara sekaligus, misalnya Jepang, Korea, dan Amerika.
#
# Pertama mem-<i>filter</i> dataframe dan memasukkannya ke dalam variabel baru. Jangan lupa lakukan juga <code>transpose()</code> untuk data ini.

# %%
# Memfilter dan transpose dataframe

df_JKA = df_pivot.loc[['Japan', 'Republic of Korea', 'United States of America'], years].transpose()
df_JKA.head(10)
# Out:
# country    Japan  Republic of Korea  United States of America
# year
# 1980     20416.0                NaN                   26852.0
# 1981     19976.0                NaN                   27574.0
# 1982     20535.0                NaN                   28226.0
# 1983     24853.0                NaN                   28280.0
# 1984     24221.0                NaN                   29267.0
# 1985     23257.0             3689.0                   29446.0
# 1986     25484.0             3458.0                   30892.0
# 1987     23663.0             3301.0                   30783.0
# 1988     22676.0             2949.0                   30388.0
# 1989     21013.0             3023.0                   30218.0

# %% [markdown]
# Setelah itu, untuk menampilkan visualisasinya, juga dapat dilakukan dengan cara yang sama persis seperti sebelumnya hanya saja kali ini diterapkan pada dataframe <code>df_JKA</code>.

# %%
# Visualisasi data dengan box plot

df_JKA.plot(kind='box', figsize=(12, 7))

plt.title('Box plot of Suicide Cases in Japan, South Korea, and USA from 1980 - 2015\n', size=18)
plt.ylabel('Number of Suicide Cases\n', size=14)
plt.xticks(size=14)
plt.yticks(size=14)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# Sekarang lihat distribusi data detailnya.

# %%
# Menampilkan statistik data

df_JKA.describe()
# Out:
# country         Japan  Republic of Korea  United States of America
# count       36.000000          31.000000                 36.000000
# mean     25469.527778        8442.903226              32617.000000
# std       4201.238147        4578.905731               4411.305955
# min      19780.000000        2949.000000              26852.000000
# 25%      21190.000000        3906.500000              30345.500000
# 50%      24605.000000        7075.000000              30893.500000
# 75%      29824.000000       12516.000000              33618.000000
# max      31881.000000       15906.000000              44189.000000

# %% [markdown]
# ## Horizontal Boxplot

# %% [markdown]
# <i>Default box plot</i> adalah berbentuk vertikal seperti contoh sebelumnya. Namun, juga dapat mengaturnya menjadi bentuk horizontal dengan menambahkan parameter <code>vert = False</code>.
#
# Misal membuat <i>box plot</i> horizontal menggunakan dataframe <code>df_JKA</code>. Perhatikan kode di bawah ini.

# %%
# Box plot horizontal

df_JKA.plot(kind='box', figsize=(12, 7), color='red', vert=False)

plt.title('Box plot of Suicide Cases in Japan, South Korea, and USA from 1980 - 2015\n', size=18)
plt.xlabel('\nNumber of Suicide Cases', size=14)
plt.xticks(size=14)
plt.yticks(size=14)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# ## Membuat Subplot

# %% [markdown]
# Terkadang ingin menampilkan beberapa plot di dalam satu <i>figure</i>. Misal ingin melakukan perbandingan dari dua plot, maka perlu menempatkannya bersebelahan agar lebih mudah dibandingkan.
#
# Untuk memvisualisasikan beberapa plot bersamaan, gunakan cara <i>explicit</i> dengan membuat <code>figure</code> dan membaginya menjadi <code>subplot</code> yang masing-masingnya mengandung sebuah plot.
#
# Secara umum, dapat menuliskannya sebagai berikut:<br>
# ```python
#     fig = plt.figure() # membuat figure
#     ax = fig.add_subplot(nrows, ncols, plot_number) # membuat subplots
# ```
#  dimana
#  * `nrows` adalah jumlah baris axes yang diinginkan
#  * `ncols` adalah jumlah kolom axes yang diinginkan
#  * `plot_number` adalah nomor plotnya, digunakan untuk mengidentifikasi subplot tertentu. `plot_number` dimulai berurutan dari angka 1 sampai angka maksimumnya adalah `nrows` * `ncols`.
#
# Sebagai contoh misal ingin membuat 2 plot (<i>box plot</i> dan <i>line plot</i>) bersebelahan yang artinya kita harus membuat <i>figure</i> yang terdiri dari 1 baris axes dan 2 kolom axes. Perhatikan kode berikut.

# %%
# Membuat subplot

fig = plt.figure() # membuat figure

ax0 = fig.add_subplot(1, 2, 1) # menambahkan subplot 1 (1 baris, 2 kolom, plot pertama)
ax1 = fig.add_subplot(1, 2, 2) # menambahkan subplot 2 (1 baris, 2 kolom, plot kedua). 

# Subplot 1: Box plot
df_JKA.plot(kind='box', color='blue', vert=False, figsize=(20, 7), ax=ax0) 
ax0.set_title('Box plot of Suicide Cases in Japan, South Korea, and USA from 1980 - 2015', size=14)
ax0.set_xlabel('Number of Suicide Cases')
ax0.set_ylabel('Countries')

# Subplot 2: Line plot
df_JKA.plot(kind='line', figsize=(20, 7), ax=ax1) 
ax1.set_title ('Line Plot of Suicide Cases in Japan, South Korea, and USA from 1980 - 2015', size=14)
ax1.set_ylabel('Number of Suicide Cases')
ax1.set_xlabel('Years')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# Jika <code>nrows</code>, <code>ncols</code>, dan <code>plot_number</code>-nya kurang dari 10, dapat dituliskan tanpa dipisahkan koma.
#
# Jadi,
#
# ```python
#    subplot(211) == subplot(2, 1, 1)
# ```

# %% [markdown]
# ---
#
#
# Semoga Bermanfaat dan jangan lupa main-main kesini: <a href="https://nurpurwanto.github.io/">**nurpurwanto**</a> Terimakasih.
#
# ---
